# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer
from transformers import BertTokenizer, BertModel
import torch
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler

def load_and_preprocess_data(data_path):
    bug_reports = pd.read_csv(data_path)

    bug_reports['creation_date'] = pd.to_datetime(bug_reports['creation_date'], errors='coerce')
    bug_reports['resolution_date'] = pd.to_datetime(bug_reports['resolution_date'])
    bug_reports['bug_fix_time'] = (bug_reports['resolution_date'] - bug_reports['creation_date']).dt.days
    bug_reports = bug_reports.dropna(subset=['bug_fix_time', 'short_description'])

    threshold = 10
    bug_reports['bug_class'] = np.where(bug_reports['bug_fix_time'] <= threshold, 'short-lived', 'long-lived')

    return bug_reports

def extract_tfidf_features(bug_reports):
    tfidf_vectorizer = TfidfVectorizer(max_features=128, stop_words='english')
    tfidf_features = tfidf_vectorizer.fit_transform(bug_reports['short_description']).toarray()

    return tfidf_features

def extract_bert_features(bug_reports):
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = BertModel.from_pretrained('bert-base-uncased')

    def extract_bert_feature(text):
        inputs = tokenizer(text, return_tensors="pt", truncation=True)
        outputs = model(**inputs)
        return outputs.last_hidden_state.mean(dim=1).squeeze().detach().numpy()

    bert_features = np.array(bug_reports['short_description'].apply(extract_bert_feature).tolist())
    bert_features = torch.tensor(bert_features)

    return bert_features

def train_and_evaluate_classifier(X_train, X_test, y_train, y_test, classifier, feature_type):
    classifier.fit(X_train, y_train)
    predictions = classifier.predict(X_test)

    cm = confusion_matrix(y_test, predictions)
    balanced_accuracy = np.mean([cm[i, i] / np.sum(cm[i]) for i in range(len(np.unique(y_test)))])
    
    print(f'{classifier.__class__.__name__} Accuracy ({feature_type}): {accuracy_score(y_test, predictions)}')
    print(f'{classifier.__class__.__name__} Balanced Accuracy ({feature_type}): {balanced_accuracy}')
    print(f'Classification Report for {classifier.__class__.__name__} ({feature_type}):\n{classification_report(y_test, predictions)}')

    return balanced_accuracy

def plot_bar_chart(accuracies_tfidf, accuracies_bert, classifiers):
    datasets = ['Mozilla', 'Eclipse', 'GCC', 'GNOME', 'WineHQ', 'FreeDesktop']
    bar_width = 0.35
    opacity = 0.8

    for idx, dataset in enumerate(datasets):
        plt.figure(figsize=(12, 6))
        index = np.arange(len(classifiers))

        for i, classifier in enumerate(classifiers):
            tfidf_val = accuracies_tfidf[idx][i]
            bert_val = accuracies_bert[idx][i]

            plt.bar(index[i], tfidf_val, bar_width,
                    alpha=opacity,
                    color='skyblue',
                    label=f'{classifier} TF-IDF')

            plt.bar(index[i] + bar_width, bert_val, bar_width,
                    alpha=opacity,
                    color='lightcoral',
                    label=f'{classifier} BERT')

            plt.text(index[i], tfidf_val + 0.02, f'{tfidf_val:.2f}', ha='center', va='bottom')
            plt.text(index[i] + bar_width, bert_val + 0.02, f'{bert_val:.2f}', ha='center', va='bottom')

        plt.xlabel('Classifiers')
        plt.ylabel('Balanced Accuracy')
        plt.title(f'Balanced Accuracy Comparison for {dataset} Dataset')
        plt.xticks(index + bar_width / 2, classifiers)
        plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
        plt.tight_layout()

        plt.show()

# Load and preprocess data for different projects
data_paths = [
    r'C:\Users\Admin\Desktop\New folder\mozilla_bug_report_data.csv',
    r'C:\Users\Admin\Desktop\New folder\eclipse_bug_report_data.csv',
    r'C:\Users\Admin\Desktop\New folder\gcc_bug_report_data.csv',
    r'C:\Users\Admin\Desktop\New folder\gnome_bug_report_data.csv',
    r'C:\Users\Admin\Desktop\New folder\winehq_bug_report_data.csv',
    r'C:\Users\Admin\Desktop\New folder\freedesktop_bug_report_data.csv'
]

classifiers = ['KNN', 'NB', 'NN', 'RF', 'SVM']

# Initialize empty lists to collect mean balanced accuracies for each dataset and feature extraction method
mean_accuracies_tfidf = []
mean_accuracies_bert = []

for data_path in data_paths:
    print(f'Processing data from: {data_path}')
    bug_reports = load_and_preprocess_data(data_path)

    X_tfidf = extract_tfidf_features(bug_reports)
    X_bert = extract_bert_features(bug_reports)
    y = bug_reports['bug_class']

    # Initialize StratifiedKFold
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

    # Initialize empty lists to collect balanced accuracies for each fold and feature extraction method
    accuracies_tfidf = []
    accuracies_bert = []

    for train_index, test_index in skf.split(X_tfidf, y):
        X_train_tfidf, X_test_tfidf = X_tfidf[train_index], X_tfidf[test_index]
        y_train_tfidf, y_test_tfidf = y.iloc[train_index], y.iloc[test_index]

        X_train_bert, X_test_bert = X_bert[train_index], X_bert[test_index]
        y_train_bert, y_test_bert = y.iloc[train_index], y.iloc[test_index]

        # Scale BERT features
        scaler = MinMaxScaler()
        X_train_bert = scaler.fit_transform(X_train_bert)
        X_test_bert = scaler.transform(X_test_bert)

        # Collect balanced accuracies for each fold and feature extraction method
        accuracies_tfidf.append([
            train_and_evaluate_classifier(
                X_train_tfidf,
                X_test_tfidf,
                y_train_tfidf,
                y_test_tfidf,
                KNeighborsClassifier(),
                'TF-IDF'
            ),
            train_and_evaluate_classifier(
                X_train_tfidf,
                X_test_tfidf,
                y_train_tfidf,
                y_test_tfidf,
                MultinomialNB(),
                'TF-IDF'
            ),
            train_and_evaluate_classifier(
                X_train_tfidf,
                X_test_tfidf,
                y_train_tfidf,
                y_test_tfidf,
                MLPClassifier(),
                'TF-IDF'
            ),
            train_and_evaluate_classifier(
                X_train_tfidf,
                X_test_tfidf,
                y_train_tfidf,
                y_test_tfidf,
                RandomForestClassifier(),
                'TF-IDF'
            ),
            train_and_evaluate_classifier(
                X_train_tfidf,
                X_test_tfidf,
                y_train_tfidf,
                y_test_tfidf,
                SVC(),
                'TF-IDF'
            )
        ])

        accuracies_bert.append([
            train_and_evaluate_classifier(
                X_train_bert,
                X_test_bert,
                y_train_bert,
                y_test_bert,
                KNeighborsClassifier(),
                'BERT'
            ),
            train_and_evaluate_classifier(
                X_train_bert,
                X_test_bert,
                y_train_bert,
                y_test_bert,
                MultinomialNB(),
                'BERT'
            ),
            train_and_evaluate_classifier(
                X_train_bert,
                X_test_bert,
                y_train_bert,
                y_test_bert,
                MLPClassifier(),
                'BERT'
            ),
            train_and_evaluate_classifier(
                X_train_bert,
                X_test_bert,
                y_train_bert,
                y_test_bert,
                RandomForestClassifier(),
                'BERT'
            ),
            train_and_evaluate_classifier(
                X_train_bert,
                X_test_bert,
                y_train_bert,
                y_test_bert,
                SVC(),
                'BERT'
            )
        ])

    # Calculate mean balanced accuracies for each feature extraction method
    mean_accuracies_tfidf.append(np.mean(accuracies_tfidf, axis=0))
    mean_accuracies_bert.append(np.mean(accuracies_bert, axis=0))

# Plot bar charts for each dataset
plot_bar_chart(mean_accuracies_tfidf, mean_accuracies_bert, classifiers)
# Out:
# Processing data from: C:\Users\Admin\Desktop\New folder\mozilla_bug_report_data.csv
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (TF-IDF): 0.553
# KNeighborsClassifier Balanced Accuracy (TF-IDF): 0.5056107431935246
# Classification Report for KNeighborsClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.61      0.73      0.66       604
#  short-lived       0.41      0.28      0.33       396
#
#     accuracy                           0.55      1000
#    macro avg       0.51      0.51      0.50      1000
# weighted avg       0.53      0.55      0.53      1000
#
# MultinomialNB Accuracy (TF-IDF): 0.591
# MultinomialNB Balanced Accuracy (TF-IDF): 0.5083701250919794
# Classification Report for MultinomialNB (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.61      0.91      0.73       604
#  short-lived       0.44      0.11      0.18       396
#
#     accuracy                           0.59      1000
#    macro avg       0.52      0.51      0.45      1000
# weighted avg       0.54      0.59      0.51      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier Accuracy (TF-IDF): 0.604
# MLPClassifier Balanced Accuracy (TF-IDF): 0.5456552277744331
# Classification Report for MLPClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.83      0.72       604
#  short-lived       0.50      0.27      0.35       396
#
#     accuracy                           0.60      1000
#    macro avg       0.57      0.55      0.53      1000
# weighted avg       0.58      0.60      0.57      1000
#
# RandomForestClassifier Accuracy (TF-IDF): 0.613
# RandomForestClassifier Balanced Accuracy (TF-IDF): 0.5513663121279015
# Classification Report for RandomForestClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.85      0.73       604
#  short-lived       0.52      0.26      0.34       396
#
#     accuracy                           0.61      1000
#    macro avg       0.58      0.55      0.53      1000
# weighted avg       0.59      0.61      0.57      1000
#
# SVC Accuracy (TF-IDF): 0.602
# SVC Balanced Accuracy (TF-IDF): 0.5253026958324971
# Classification Report for SVC (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.89      0.73       604
#  short-lived       0.49      0.16      0.24       396
#
#     accuracy                           0.60      1000
#    macro avg       0.55      0.53      0.48      1000
# weighted avg       0.57      0.60      0.54      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (BERT): 0.586
# KNeighborsClassifier Balanced Accuracy (BERT): 0.548147033246371
# Classification Report for KNeighborsClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.73      0.68       604
#  short-lived       0.47      0.37      0.41       396
#
#     accuracy                           0.59      1000
#    macro avg       0.55      0.55      0.55      1000
# weighted avg       0.57      0.59      0.57      1000
#
# MultinomialNB Accuracy (BERT): 0.634
# MultinomialNB Balanced Accuracy (BERT): 0.5517927620576627
# Classification Report for MultinomialNB (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.95      0.76       604
#  short-lived       0.66      0.16      0.25       396
#
#     accuracy                           0.63      1000
#    macro avg       0.65      0.55      0.51      1000
# weighted avg       0.64      0.63      0.56      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier Accuracy (BERT): 0.618
# MLPClassifier Balanced Accuracy (BERT): 0.5611579369857516
# Classification Report for MLPClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.83      0.73       604
#  short-lived       0.53      0.29      0.37       396
#
#     accuracy                           0.62      1000
#    macro avg       0.59      0.56      0.55      1000
# weighted avg       0.60      0.62      0.59      1000
#
# RandomForestClassifier Accuracy (BERT): 0.605
# RandomForestClassifier Balanced Accuracy (BERT): 0.5251772693825674
# Classification Report for RandomForestClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.91      0.74       604
#  short-lived       0.50      0.14      0.22       396
#
#     accuracy                           0.60      1000
#    macro avg       0.56      0.53      0.48      1000
# weighted avg       0.57      0.60      0.53      1000
#
# SVC Accuracy (BERT): 0.627
# SVC Balanced Accuracy (BERT): 0.5538246705465248
# Classification Report for SVC (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.91      0.75       604
#  short-lived       0.58      0.20      0.30       396
#
#     accuracy                           0.63      1000
#    macro avg       0.61      0.55      0.52      1000
# weighted avg       0.61      0.63      0.57      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (TF-IDF): 0.591
# KNeighborsClassifier Balanced Accuracy (TF-IDF): 0.5435898722322563
# Classification Report for KNeighborsClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.77      0.70       604
#  short-lived       0.48      0.32      0.38       396
#
#     accuracy                           0.59      1000
#    macro avg       0.55      0.54      0.54      1000
# weighted avg       0.57      0.59      0.57      1000
#
# MultinomialNB Accuracy (TF-IDF): 0.611
# MultinomialNB Balanced Accuracy (TF-IDF): 0.5310137801859656
# Classification Report for MultinomialNB (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.92      0.74       604
#  short-lived       0.53      0.15      0.23       396
#
#     accuracy                           0.61      1000
#    macro avg       0.58      0.53      0.48      1000
# weighted avg       0.59      0.61      0.54      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier Accuracy (TF-IDF): 0.589
# MLPClassifier Balanced Accuracy (TF-IDF): 0.5323683858452071
# Classification Report for MLPClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.80      0.70       604
#  short-lived       0.47      0.26      0.33       396
#
#     accuracy                           0.59      1000
#    macro avg       0.54      0.53      0.52      1000
# weighted avg       0.56      0.59      0.56      1000
#
# RandomForestClassifier Accuracy (TF-IDF): 0.588
# RandomForestClassifier Balanced Accuracy (TF-IDF): 0.5258880192655027
# Classification Report for RandomForestClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.82      0.71       604
#  short-lived       0.46      0.23      0.30       396
#
#     accuracy                           0.59      1000
#    macro avg       0.54      0.53      0.51      1000
# weighted avg       0.56      0.59      0.55      1000
#
# SVC Accuracy (TF-IDF): 0.606
# SVC Balanced Accuracy (TF-IDF): 0.5329620710415413
# Classification Report for SVC (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.88      0.73       604
#  short-lived       0.51      0.18      0.27       396
#
#     accuracy                           0.61      1000
#    macro avg       0.56      0.53      0.50      1000
# weighted avg       0.58      0.61      0.55      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (BERT): 0.596
# KNeighborsClassifier Balanced Accuracy (BERT): 0.5594688607933641
# Classification Report for KNeighborsClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.65      0.74      0.69       604
#  short-lived       0.49      0.38      0.43       396
#
#     accuracy                           0.60      1000
#    macro avg       0.57      0.56      0.56      1000
# weighted avg       0.58      0.60      0.59      1000
#
# MultinomialNB Accuracy (BERT): 0.611
# MultinomialNB Balanced Accuracy (BERT): 0.5288397217205164
# Classification Report for MultinomialNB (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.92      0.74       604
#  short-lived       0.54      0.13      0.21       396
#
#     accuracy                           0.61      1000
#    macro avg       0.58      0.53      0.48      1000
# weighted avg       0.59      0.61      0.53      1000
#
# MLPClassifier Accuracy (BERT): 0.615
# MLPClassifier Balanced Accuracy (BERT): 0.5234547461368654
# Classification Report for MLPClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.96      0.75       604
#  short-lived       0.60      0.08      0.15       396
#
#     accuracy                           0.61      1000
#    macro avg       0.61      0.52      0.45      1000
# weighted avg       0.61      0.61      0.51      1000
#
# RandomForestClassifier Accuracy (BERT): 0.624
# RandomForestClassifier Balanced Accuracy (BERT): 0.5426449929761188
# Classification Report for RandomForestClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.93      0.75       604
#  short-lived       0.60      0.15      0.24       396
#
#     accuracy                           0.62      1000
#    macro avg       0.61      0.54      0.50      1000
# weighted avg       0.62      0.62      0.55      1000
#
# SVC Accuracy (BERT): 0.621
# SVC Balanced Accuracy (BERT): 0.5462489129707673
# Classification Report for SVC (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.91      0.74       604
#  short-lived       0.56      0.19      0.28       396
#
#     accuracy                           0.62      1000
#    macro avg       0.60      0.55      0.51      1000
# weighted avg       0.60      0.62      0.56      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (TF-IDF): 0.575
# KNeighborsClassifier Balanced Accuracy (TF-IDF): 0.5259967221887751
# Classification Report for KNeighborsClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.76      0.68       604
#  short-lived       0.44      0.29      0.35       396
#
#     accuracy                           0.57      1000
#    macro avg       0.53      0.53      0.52      1000
# weighted avg       0.55      0.57      0.55      1000
#
# MultinomialNB Accuracy (TF-IDF): 0.614
# MultinomialNB Balanced Accuracy (TF-IDF): 0.5326276005083952
# Classification Report for MultinomialNB (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.92      0.74       604
#  short-lived       0.55      0.14      0.22       396
#
#     accuracy                           0.61      1000
#    macro avg       0.59      0.53      0.48      1000
# weighted avg       0.59      0.61      0.54      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier Accuracy (TF-IDF): 0.573
# MLPClassifier Balanced Accuracy (TF-IDF): 0.5265151515151515
# Classification Report for MLPClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.75      0.68       604
#  short-lived       0.44      0.30      0.36       396
#
#     accuracy                           0.57      1000
#    macro avg       0.53      0.53      0.52      1000
# weighted avg       0.55      0.57      0.55      1000
#
# RandomForestClassifier Accuracy (TF-IDF): 0.611
# RandomForestClassifier Balanced Accuracy (TF-IDF): 0.5549284233059067
# Classification Report for RandomForestClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.82      0.72       604
#  short-lived       0.52      0.29      0.37       396
#
#     accuracy                           0.61      1000
#    macro avg       0.58      0.55      0.54      1000
# weighted avg       0.59      0.61      0.58      1000
#
# SVC Accuracy (TF-IDF): 0.611
# SVC Balanced Accuracy (TF-IDF): 0.5344922737306843
# Classification Report for SVC (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.90      0.74       604
#  short-lived       0.53      0.17      0.25       396
#
#     accuracy                           0.61      1000
#    macro avg       0.58      0.53      0.50      1000
# weighted avg       0.59      0.61      0.55      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (BERT): 0.602
# KNeighborsClassifier Balanced Accuracy (BERT): 0.574001605458559
# Classification Report for KNeighborsClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.66      0.71      0.68       604
#  short-lived       0.50      0.44      0.47       396
#
#     accuracy                           0.60      1000
#    macro avg       0.58      0.57      0.57      1000
# weighted avg       0.59      0.60      0.60      1000
#
# MultinomialNB Accuracy (BERT): 0.613
# MultinomialNB Balanced Accuracy (BERT): 0.5309301625526791
# Classification Report for MultinomialNB (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.93      0.74       604
#  short-lived       0.55      0.14      0.22       396
#
#     accuracy                           0.61      1000
#    macro avg       0.58      0.53      0.48      1000
# weighted avg       0.59      0.61      0.54      1000
#
# MLPClassifier Accuracy (BERT): 0.624
# MLPClassifier Balanced Accuracy (BERT): 0.5704729413338685
# Classification Report for MLPClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.65      0.83      0.73       604
#  short-lived       0.54      0.31      0.40       396
#
#     accuracy                           0.62      1000
#    macro avg       0.60      0.57      0.56      1000
# weighted avg       0.61      0.62      0.60      1000
#
# RandomForestClassifier Accuracy (BERT): 0.628
# RandomForestClassifier Balanced Accuracy (BERT): 0.5494347447989831
# Classification Report for RandomForestClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.93      0.75       604
#  short-lived       0.61      0.17      0.27       396
#
#     accuracy                           0.63      1000
#    macro avg       0.62      0.55      0.51      1000
# weighted avg       0.62      0.63      0.56      1000
#
# SVC Accuracy (BERT): 0.65
# SVC Balanced Accuracy (BERT): 0.582430262893839
# Classification Report for SVC (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.65      0.91      0.76       604
#  short-lived       0.65      0.26      0.37       396
#
#     accuracy                           0.65      1000
#    macro avg       0.65      0.58      0.56      1000
# weighted avg       0.65      0.65      0.60      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (TF-IDF): 0.539
# KNeighborsClassifier Balanced Accuracy (TF-IDF): 0.5288062746672018
# Classification Report for KNeighborsClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.58      0.60       604
#  short-lived       0.43      0.48      0.45       396
#
#     accuracy                           0.54      1000
#    macro avg       0.53      0.53      0.53      1000
# weighted avg       0.55      0.54      0.54      1000
#
# MultinomialNB Accuracy (TF-IDF): 0.6
# MultinomialNB Balanced Accuracy (TF-IDF): 0.5175597029901666
# Classification Report for MultinomialNB (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.61      0.91      0.73       604
#  short-lived       0.48      0.12      0.19       396
#
#     accuracy                           0.60      1000
#    macro avg       0.55      0.52      0.46      1000
# weighted avg       0.56      0.60      0.52      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier Accuracy (TF-IDF): 0.594
# MLPClassifier Balanced Accuracy (TF-IDF): 0.5421600107030571
# Classification Report for MLPClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.79      0.70       604
#  short-lived       0.48      0.29      0.36       396
#
#     accuracy                           0.59      1000
#    macro avg       0.55      0.54      0.53      1000
# weighted avg       0.57      0.59      0.57      1000
#
# RandomForestClassifier Accuracy (TF-IDF): 0.596
# RandomForestClassifier Balanced Accuracy (TF-IDF): 0.5346845942872432
# Classification Report for RandomForestClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.83      0.71       604
#  short-lived       0.48      0.24      0.32       396
#
#     accuracy                           0.60      1000
#    macro avg       0.55      0.53      0.52      1000
# weighted avg       0.57      0.60      0.56      1000
#
# SVC Accuracy (TF-IDF): 0.618
# SVC Balanced Accuracy (TF-IDF): 0.5476787744999666
# Classification Report for SVC (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.89      0.74       604
#  short-lived       0.55      0.21      0.30       396
#
#     accuracy                           0.62      1000
#    macro avg       0.59      0.55      0.52      1000
# weighted avg       0.60      0.62      0.57      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (BERT): 0.593
# KNeighborsClassifier Balanced Accuracy (BERT): 0.5626379690949227
# Classification Report for KNeighborsClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.65      0.71      0.68       604
#  short-lived       0.48      0.42      0.45       396
#
#     accuracy                           0.59      1000
#    macro avg       0.57      0.56      0.56      1000
# weighted avg       0.58      0.59      0.59      1000
#
# MultinomialNB Accuracy (BERT): 0.598
# MultinomialNB Balanced Accuracy (BERT): 0.5224262492474413
# Classification Report for MultinomialNB (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.89      0.73       604
#  short-lived       0.48      0.16      0.24       396
#
#     accuracy                           0.60      1000
#    macro avg       0.55      0.52      0.48      1000
# weighted avg       0.56      0.60      0.53      1000
#
# MLPClassifier Accuracy (BERT): 0.597
# MLPClassifier Balanced Accuracy (BERT): 0.580732824938123
# Classification Report for MLPClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.67      0.66      0.66       604
#  short-lived       0.49      0.50      0.50       396
#
#     accuracy                           0.60      1000
#    macro avg       0.58      0.58      0.58      1000
# weighted avg       0.60      0.60      0.60      1000
#
# RandomForestClassifier Accuracy (BERT): 0.636
# RandomForestClassifier Balanced Accuracy (BERT): 0.5591009432069035
# Classification Report for RandomForestClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.93      0.76       604
#  short-lived       0.64      0.19      0.29       396
#
#     accuracy                           0.64      1000
#    macro avg       0.64      0.56      0.52      1000
# weighted avg       0.64      0.64      0.57      1000
#
# SVC Accuracy (BERT): 0.623
# SVC Balanced Accuracy (BERT): 0.5557311525854572
# Classification Report for SVC (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.88      0.74       604
#  short-lived       0.56      0.23      0.33       396
#
#     accuracy                           0.62      1000
#    macro avg       0.60      0.56      0.53      1000
# weighted avg       0.60      0.62      0.58      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (TF-IDF): 0.569
# KNeighborsClassifier Balanced Accuracy (TF-IDF): 0.5260487498692332
# Classification Report for KNeighborsClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.73      0.67       605
#  short-lived       0.44      0.32      0.37       395
#
#     accuracy                           0.57      1000
#    macro avg       0.53      0.53      0.52      1000
# weighted avg       0.55      0.57      0.55      1000
#
# MultinomialNB Accuracy (TF-IDF): 0.623
# MultinomialNB Balanced Accuracy (TF-IDF): 0.5416779997907731
# Classification Report for MultinomialNB (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.93      0.75       605
#  short-lived       0.59      0.15      0.24       395
#
#     accuracy                           0.62      1000
#    macro avg       0.61      0.54      0.50      1000
# weighted avg       0.61      0.62      0.55      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier Accuracy (TF-IDF): 0.599
# MLPClassifier Balanced Accuracy (TF-IDF): 0.5556752798409875
# Classification Report for MLPClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.76      0.70       605
#  short-lived       0.49      0.35      0.41       395
#
#     accuracy                           0.60      1000
#    macro avg       0.57      0.56      0.55      1000
# weighted avg       0.58      0.60      0.58      1000
#
# RandomForestClassifier Accuracy (TF-IDF): 0.606
# RandomForestClassifier Balanced Accuracy (TF-IDF): 0.5504759912124699
# Classification Report for RandomForestClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.81      0.71       605
#  short-lived       0.50      0.29      0.36       395
#
#     accuracy                           0.61      1000
#    macro avg       0.57      0.55      0.54      1000
# weighted avg       0.58      0.61      0.58      1000
#
# SVC Accuracy (TF-IDF): 0.619
# SVC Balanced Accuracy (TF-IDF): 0.5427659797049901
# Classification Report for SVC (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.91      0.74       605
#  short-lived       0.55      0.18      0.27       395
#
#     accuracy                           0.62      1000
#    macro avg       0.59      0.54      0.51      1000
# weighted avg       0.60      0.62      0.56      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (BERT): 0.572
# KNeighborsClassifier Balanced Accuracy (BERT): 0.5412700073229417
# Classification Report for KNeighborsClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.69      0.66       605
#  short-lived       0.45      0.39      0.42       395
#
#     accuracy                           0.57      1000
#    macro avg       0.54      0.54      0.54      1000
# weighted avg       0.56      0.57      0.57      1000
#
# MultinomialNB Accuracy (BERT): 0.59
# MultinomialNB Balanced Accuracy (BERT): 0.5126477665027722
# Classification Report for MultinomialNB (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.61      0.88      0.72       605
#  short-lived       0.44      0.14      0.22       395
#
#     accuracy                           0.59      1000
#    macro avg       0.53      0.51      0.47      1000
# weighted avg       0.54      0.59      0.52      1000
#
# MLPClassifier Accuracy (BERT): 0.61
# MLPClassifier Balanced Accuracy (BERT): 0.5278585626111518
# Classification Report for MLPClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.92      0.74       605
#  short-lived       0.52      0.14      0.22       395
#
#     accuracy                           0.61      1000
#    macro avg       0.57      0.53      0.48      1000
# weighted avg       0.58      0.61      0.53      1000
#
# RandomForestClassifier Accuracy (BERT): 0.608
# RandomForestClassifier Balanced Accuracy (BERT): 0.5336750706140809
# Classification Report for RandomForestClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.89      0.73       605
#  short-lived       0.51      0.18      0.27       395
#
#     accuracy                           0.61      1000
#    macro avg       0.57      0.53      0.50      1000
# weighted avg       0.58      0.61      0.55      1000
#
# SVC Accuracy (BERT): 0.617
# SVC Balanced Accuracy (BERT): 0.5503399937231928
# Classification Report for SVC (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.87      0.73       605
#  short-lived       0.53      0.23      0.32       395
#
#     accuracy                           0.62      1000
#    macro avg       0.58      0.55      0.53      1000
# weighted avg       0.59      0.62      0.57      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (TF-IDF): 0.573
# KNeighborsClassifier Balanced Accuracy (TF-IDF): 0.5315514175122921
# Classification Report for KNeighborsClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.73      0.67       605
#  short-lived       0.45      0.33      0.38       395
#
#     accuracy                           0.57      1000
#    macro avg       0.54      0.53      0.53      1000
# weighted avg       0.56      0.57      0.56      1000
#
# MultinomialNB Accuracy (TF-IDF): 0.613
# MultinomialNB Balanced Accuracy (TF-IDF): 0.5329741604770374
# Classification Report for MultinomialNB (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.91      0.74       605
#  short-lived       0.54      0.15      0.24       395
#
#     accuracy                           0.61      1000
#    macro avg       0.58      0.53      0.49      1000
# weighted avg       0.59      0.61      0.54      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier Accuracy (TF-IDF): 0.58
# MLPClassifier Balanced Accuracy (TF-IDF): 0.538215294486871
# Classification Report for MLPClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.74      0.68       605
#  short-lived       0.46      0.34      0.39       395
#
#     accuracy                           0.58      1000
#    macro avg       0.54      0.54      0.53      1000
# weighted avg       0.56      0.58      0.57      1000
#
# RandomForestClassifier Accuracy (TF-IDF): 0.605
# RandomForestClassifier Balanced Accuracy (TF-IDF): 0.5426195208703839
# Classification Report for RandomForestClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.84      0.72       605
#  short-lived       0.50      0.25      0.33       395
#
#     accuracy                           0.60      1000
#    macro avg       0.57      0.54      0.52      1000
# weighted avg       0.58      0.60      0.57      1000
#
# SVC Accuracy (TF-IDF): 0.598
# SVC Balanced Accuracy (TF-IDF): 0.5232137252850717
# Classification Report for SVC (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.88      0.73       605
#  short-lived       0.47      0.17      0.25       395
#
#     accuracy                           0.60      1000
#    macro avg       0.55      0.52      0.49      1000
# weighted avg       0.56      0.60      0.54      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (BERT): 0.586
# KNeighborsClassifier Balanced Accuracy (BERT): 0.5515221257453709
# Classification Report for KNeighborsClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.72      0.68       605
#  short-lived       0.47      0.39      0.43       395
#
#     accuracy                           0.59      1000
#    macro avg       0.56      0.55      0.55      1000
# weighted avg       0.57      0.59      0.58      1000
#
# MultinomialNB Accuracy (BERT): 0.607
# MultinomialNB Balanced Accuracy (BERT): 0.523621717752903
# Classification Report for MultinomialNB (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.92      0.74       605
#  short-lived       0.51      0.13      0.20       395
#
#     accuracy                           0.61      1000
#    macro avg       0.56      0.52      0.47      1000
# weighted avg       0.58      0.61      0.53      1000
#
# MLPClassifier Accuracy (BERT): 0.605
# MLPClassifier Balanced Accuracy (BERT): 0.5689821110994874
# Classification Report for MLPClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.65      0.74      0.69       605
#  short-lived       0.50      0.40      0.44       395
#
#     accuracy                           0.60      1000
#    macro avg       0.58      0.57      0.57      1000
# weighted avg       0.59      0.60      0.59      1000
#
# RandomForestClassifier Accuracy (BERT): 0.606
# RandomForestClassifier Balanced Accuracy (BERT): 0.528067789517732
# Classification Report for RandomForestClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.90      0.73       605
#  short-lived       0.50      0.16      0.24       395
#
#     accuracy                           0.61      1000
#    macro avg       0.56      0.53      0.49      1000
# weighted avg       0.57      0.61      0.54      1000
#
# SVC Accuracy (BERT): 0.623
# SVC Balanced Accuracy (BERT): 0.5513442828747777
# Classification Report for SVC (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.89      0.74       605
#  short-lived       0.56      0.21      0.31       395
#
#     accuracy                           0.62      1000
#    macro avg       0.60      0.55      0.52      1000
# weighted avg       0.60      0.62      0.57      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (TF-IDF): 0.564
# KNeighborsClassifier Balanced Accuracy (TF-IDF): 0.5122502353802698
# Classification Report for KNeighborsClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.61      0.76      0.68       605
#  short-lived       0.42      0.27      0.33       395
#
#     accuracy                           0.56      1000
#    macro avg       0.52      0.51      0.50      1000
# weighted avg       0.54      0.56      0.54      1000
#
# MultinomialNB Accuracy (TF-IDF): 0.614
# MultinomialNB Balanced Accuracy (TF-IDF): 0.5338006067580291
# Classification Report for MultinomialNB (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.92      0.74       605
#  short-lived       0.54      0.15      0.24       395
#
#     accuracy                           0.61      1000
#    macro avg       0.58      0.53      0.49      1000
# weighted avg       0.59      0.61      0.54      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier Accuracy (TF-IDF): 0.584
# MLPClassifier Balanced Accuracy (TF-IDF): 0.5243853959619207
# Classification Report for MLPClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.81      0.70       605
#  short-lived       0.45      0.24      0.31       395
#
#     accuracy                           0.58      1000
#    macro avg       0.54      0.52      0.51      1000
# weighted avg       0.55      0.58      0.55      1000
#
# RandomForestClassifier Accuracy (TF-IDF): 0.601
# RandomForestClassifier Balanced Accuracy (TF-IDF): 0.5406318652578721
# Classification Report for RandomForestClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.83      0.72       605
#  short-lived       0.49      0.25      0.33       395
#
#     accuracy                           0.60      1000
#    macro avg       0.56      0.54      0.52      1000
# weighted avg       0.57      0.60      0.56      1000
#
# SVC Accuracy (TF-IDF): 0.621
# SVC Balanced Accuracy (TF-IDF): 0.5439794957631552
# Classification Report for SVC (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.91      0.74       605
#  short-lived       0.56      0.18      0.27       395
#
#     accuracy                           0.62      1000
#    macro avg       0.60      0.54      0.51      1000
# weighted avg       0.60      0.62      0.56      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (BERT): 0.602
# KNeighborsClassifier Balanced Accuracy (BERT): 0.5678209017679674
# Classification Report for KNeighborsClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.65      0.73      0.69       605
#  short-lived       0.50      0.41      0.45       395
#
#     accuracy                           0.60      1000
#    macro avg       0.57      0.57      0.57      1000
# weighted avg       0.59      0.60      0.59      1000
#
# MultinomialNB Accuracy (BERT): 0.616
# MultinomialNB Balanced Accuracy (BERT): 0.5350141228161941
# Classification Report for MultinomialNB (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.92      0.74       605
#  short-lived       0.55      0.15      0.24       395
#
#     accuracy                           0.62      1000
#    macro avg       0.59      0.54      0.49      1000
# weighted avg       0.60      0.62      0.54      1000
#
# MLPClassifier Accuracy (BERT): 0.636
# MLPClassifier Balanced Accuracy (BERT): 0.5634062140391254
# Classification Report for MLPClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.91      0.75       605
#  short-lived       0.61      0.22      0.32       395
#
#     accuracy                           0.64      1000
#    macro avg       0.63      0.56      0.54      1000
# weighted avg       0.63      0.64      0.58      1000
#
# RandomForestClassifier Accuracy (BERT): 0.619
# RandomForestClassifier Balanced Accuracy (BERT): 0.5388115911706245
# Classification Report for RandomForestClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.92      0.75       605
#  short-lived       0.56      0.16      0.25       395
#
#     accuracy                           0.62      1000
#    macro avg       0.59      0.54      0.50      1000
# weighted avg       0.60      0.62      0.55      1000
#
# SVC Accuracy (BERT): 0.633
# SVC Balanced Accuracy (BERT): 0.5622450047076054
# Classification Report for SVC (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.90      0.75       605
#  short-lived       0.59      0.23      0.33       395
#
#     accuracy                           0.63      1000
#    macro avg       0.62      0.56      0.54      1000
# weighted avg       0.62      0.63      0.58      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (TF-IDF): 0.604
# KNeighborsClassifier Balanced Accuracy (TF-IDF): 0.5545349932001256
# Classification Report for KNeighborsClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.79      0.71       605
#  short-lived       0.50      0.32      0.39       395
#
#     accuracy                           0.60      1000
#    macro avg       0.57      0.55      0.55      1000
# weighted avg       0.58      0.60      0.58      1000
#
# MultinomialNB Accuracy (TF-IDF): 0.588
# MultinomialNB Balanced Accuracy (TF-IDF): 0.5026467203682393
# Classification Report for MultinomialNB (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.61      0.91      0.73       605
#  short-lived       0.41      0.10      0.16       395
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.50      0.44      1000
# weighted avg       0.53      0.59      0.50      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier Accuracy (TF-IDF): 0.585
# MLPClassifier Balanced Accuracy (TF-IDF): 0.5238937127314572
# Classification Report for MLPClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.81      0.70       605
#  short-lived       0.45      0.23      0.31       395
#
#     accuracy                           0.58      1000
#    macro avg       0.54      0.52      0.51      1000
# weighted avg       0.55      0.58      0.55      1000
#
# RandomForestClassifier Accuracy (TF-IDF): 0.595
# RandomForestClassifier Balanced Accuracy (TF-IDF): 0.5312794225337378
# Classification Report for RandomForestClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.83      0.71       605
#  short-lived       0.47      0.23      0.31       395
#
#     accuracy                           0.59      1000
#    macro avg       0.55      0.53      0.51      1000
# weighted avg       0.56      0.59      0.55      1000
#
# SVC Accuracy (TF-IDF): 0.593
# SVC Balanced Accuracy (TF-IDF): 0.5124908463228371
# Classification Report for SVC (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.61      0.90      0.73       605
#  short-lived       0.45      0.13      0.20       395
#
#     accuracy                           0.59      1000
#    macro avg       0.53      0.51      0.46      1000
# weighted avg       0.55      0.59      0.52      1000
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (BERT): 0.595
# KNeighborsClassifier Balanced Accuracy (BERT): 0.5580813892666597
# Classification Report for KNeighborsClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.65      0.73      0.69       605
#  short-lived       0.48      0.38      0.43       395
#
#     accuracy                           0.59      1000
#    macro avg       0.56      0.56      0.56      1000
# weighted avg       0.58      0.59      0.58      1000
#
# MultinomialNB Accuracy (BERT): 0.603
# MultinomialNB Balanced Accuracy (BERT): 0.5220734386442096
# Classification Report for MultinomialNB (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.62      0.91      0.73       605
#  short-lived       0.49      0.14      0.21       395
#
#     accuracy                           0.60      1000
#    macro avg       0.55      0.52      0.47      1000
# weighted avg       0.57      0.60      0.53      1000
#
# MLPClassifier Accuracy (BERT): 0.612
# MLPClassifier Balanced Accuracy (BERT): 0.5813578826237054
# Classification Report for MLPClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.66      0.73      0.69       605
#  short-lived       0.51      0.44      0.47       395
#
# ...
#
#     accuracy                           0.62       768
#    macro avg       0.56      0.54      0.53       768
# weighted avg       0.58      0.62      0.58       768
#
# SVC Accuracy (TF-IDF): 0.62890625
# SVC Balanced Accuracy (TF-IDF): 0.5274305555555555
# Classification Report for SVC (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.93      0.76       480
#  short-lived       0.52      0.12      0.20       288
#
#     accuracy                           0.63       768
#    macro avg       0.58      0.53      0.48       768
# weighted avg       0.60      0.63      0.55       768
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (BERT): 0.5911458333333334
# KNeighborsClassifier Balanced Accuracy (BERT): 0.5416666666666667
# Classification Report for KNeighborsClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.65      0.74      0.69       480
#  short-lived       0.44      0.34      0.39       288
#
#     accuracy                           0.59       768
#    macro avg       0.55      0.54      0.54       768
# weighted avg       0.57      0.59      0.58       768
#
# MultinomialNB Accuracy (BERT): 0.6223958333333334
# MultinomialNB Balanced Accuracy (BERT): 0.5041666666666667
# Classification Report for MultinomialNB (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.98      0.76       480
#  short-lived       0.45      0.03      0.06       288
#
#     accuracy                           0.62       768
#    macro avg       0.54      0.50      0.41       768
# weighted avg       0.56      0.62      0.50       768
#
# MLPClassifier Accuracy (BERT): 0.625
# MLPClassifier Balanced Accuracy (BERT): 0.5361111111111111
# Classification Report for MLPClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.89      0.75       480
#  short-lived       0.50      0.18      0.27       288
#
#     accuracy                           0.62       768
#    macro avg       0.57      0.54      0.51       768
# weighted avg       0.59      0.62      0.57       768
#
# RandomForestClassifier Accuracy (BERT): 0.6380208333333334
# RandomForestClassifier Balanced Accuracy (BERT): 0.5354166666666667
# Classification Report for RandomForestClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.95      0.77       480
#  short-lived       0.58      0.12      0.21       288
#
#     accuracy                           0.64       768
#    macro avg       0.61      0.54      0.49       768
# weighted avg       0.62      0.64      0.56       768
#
# SVC Accuracy (BERT): 0.6458333333333334
# SVC Balanced Accuracy (BERT): 0.5368055555555555
# Classification Report for SVC (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.97      0.77       480
#  short-lived       0.69      0.10      0.18       288
#
#     accuracy                           0.65       768
#    macro avg       0.67      0.54      0.48       768
# weighted avg       0.66      0.65      0.55       768
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (TF-IDF): 0.5299479166666666
# KNeighborsClassifier Balanced Accuracy (TF-IDF): 0.515625
# Classification Report for KNeighborsClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.57      0.60       480
#  short-lived       0.39      0.46      0.42       288
#
#     accuracy                           0.53       768
#    macro avg       0.51      0.52      0.51       768
# weighted avg       0.55      0.53      0.54       768
#
# MultinomialNB Accuracy (TF-IDF): 0.62109375
# MultinomialNB Balanced Accuracy (TF-IDF): 0.5197916666666667
# Classification Report for MultinomialNB (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.93      0.75       480
#  short-lived       0.48      0.11      0.18       288
#
#     accuracy                           0.62       768
#    macro avg       0.56      0.52      0.47       768
# weighted avg       0.58      0.62      0.54       768
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier Accuracy (TF-IDF): 0.6067708333333334
# MLPClassifier Balanced Accuracy (TF-IDF): 0.5388888888888889
# Classification Report for MLPClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.65      0.81      0.72       480
#  short-lived       0.46      0.27      0.34       288
#
#     accuracy                           0.61       768
#    macro avg       0.55      0.54      0.53       768
# weighted avg       0.58      0.61      0.58       768
#
# RandomForestClassifier Accuracy (TF-IDF): 0.6145833333333334
# RandomForestClassifier Balanced Accuracy (TF-IDF): 0.5465277777777777
# Classification Report for RandomForestClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.65      0.82      0.73       480
#  short-lived       0.48      0.27      0.35       288
#
#     accuracy                           0.61       768
#    macro avg       0.56      0.55      0.54       768
# weighted avg       0.59      0.61      0.58       768
#
# SVC Accuracy (TF-IDF): 0.6158854166666666
# SVC Balanced Accuracy (TF-IDF): 0.5295138888888888
# Classification Report for SVC (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.88      0.74       480
#  short-lived       0.47      0.18      0.26       288
#
#     accuracy                           0.62       768
#    macro avg       0.56      0.53      0.50       768
# weighted avg       0.58      0.62      0.56       768
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (BERT): 0.5807291666666666
# KNeighborsClassifier Balanced Accuracy (BERT): 0.5256944444444445
# Classification Report for KNeighborsClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.75      0.69       480
#  short-lived       0.42      0.31      0.35       288
#
#     accuracy                           0.58       768
#    macro avg       0.53      0.53      0.52       768
# weighted avg       0.56      0.58      0.56       768
#
# MultinomialNB Accuracy (BERT): 0.6263020833333334
# MultinomialNB Balanced Accuracy (BERT): 0.5059027777777778
# Classification Report for MultinomialNB (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.99      0.77       480
#  short-lived       0.54      0.02      0.05       288
#
#     accuracy                           0.63       768
#    macro avg       0.58      0.51      0.41       768
# weighted avg       0.59      0.63      0.50       768
#
# MLPClassifier Accuracy (BERT): 0.5703125
# MLPClassifier Balanced Accuracy (BERT): 0.5145833333333334
# Classification Report for MLPClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.74      0.68       480
#  short-lived       0.40      0.29      0.34       288
#
#     accuracy                           0.57       768
#    macro avg       0.52      0.51      0.51       768
# weighted avg       0.55      0.57      0.55       768
#
# RandomForestClassifier Accuracy (BERT): 0.62109375
# RandomForestClassifier Balanced Accuracy (BERT): 0.5184027777777778
# Classification Report for RandomForestClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.93      0.75       480
#  short-lived       0.48      0.11      0.18       288
#
#     accuracy                           0.62       768
#    macro avg       0.56      0.52      0.46       768
# weighted avg       0.58      0.62      0.54       768
#
# SVC Accuracy (BERT): 0.6223958333333334
# SVC Balanced Accuracy (BERT): 0.5131944444444444
# Classification Report for SVC (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.95      0.76       480
#  short-lived       0.48      0.08      0.13       288
#
#     accuracy                           0.62       768
#    macro avg       0.55      0.51      0.45       768
# weighted avg       0.57      0.62      0.52       768
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# KNeighborsClassifier Accuracy (TF-IDF): 0.5807291666666666
# KNeighborsClassifier Balanced Accuracy (TF-IDF): 0.5064796772113845
# Classification Report for KNeighborsClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.80      0.71       481
#  short-lived       0.39      0.21      0.27       287
#
#     accuracy                           0.58       768
#    macro avg       0.51      0.51      0.49       768
# weighted avg       0.54      0.58      0.54       768
#
# MultinomialNB Accuracy (TF-IDF): 0.6302083333333334
# MultinomialNB Balanced Accuracy (TF-IDF): 0.5241982802958413
# Classification Report for MultinomialNB (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.94      0.76       481
#  short-lived       0.53      0.10      0.17       287
#
#     accuracy                           0.63       768
#    macro avg       0.58      0.52      0.47       768
# weighted avg       0.60      0.63      0.54       768
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier Accuracy (TF-IDF): 0.6002604166666666
# MLPClassifier Balanced Accuracy (TF-IDF): 0.5171535781291878
# Classification Report for MLPClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.85      0.73       481
#  short-lived       0.42      0.19      0.26       287
#
#     accuracy                           0.60       768
#    macro avg       0.53      0.52      0.49       768
# weighted avg       0.56      0.60      0.55       768
#
# RandomForestClassifier Accuracy (TF-IDF): 0.5989583333333334
# RandomForestClassifier Balanced Accuracy (TF-IDF): 0.517519395568176
# Classification Report for RandomForestClassifier (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.84      0.72       481
#  short-lived       0.42      0.20      0.27       287
#
#     accuracy                           0.60       768
#    macro avg       0.53      0.52      0.50       768
# weighted avg       0.56      0.60      0.55       768
#
# SVC Accuracy (TF-IDF): 0.61328125
# SVC Balanced Accuracy (TF-IDF): 0.5163060406962846
# Classification Report for SVC (TF-IDF):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.90      0.74       481
#  short-lived       0.44      0.13      0.20       287
#
#     accuracy                           0.61       768
#    macro avg       0.54      0.52      0.47       768
# weighted avg       0.56      0.61      0.54       768
#
# KNeighborsClassifier Accuracy (BERT): 0.59375
# KNeighborsClassifier Balanced Accuracy (BERT): 0.5463863756546683
# Classification Report for KNeighborsClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.66      0.73      0.69       481
#  short-lived       0.45      0.36      0.40       287
#
#     accuracy                           0.59       768
#    macro avg       0.55      0.55      0.55       768
# weighted avg       0.58      0.59      0.58       768
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:211: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# MultinomialNB Accuracy (BERT): 0.6328125
# MultinomialNB Balanced Accuracy (BERT): 0.5150347345469297
# Classification Report for MultinomialNB (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.98      0.77       481
#  short-lived       0.61      0.05      0.09       287
#
#     accuracy                           0.63       768
#    macro avg       0.62      0.52      0.43       768
# weighted avg       0.62      0.63      0.52       768
#
# MLPClassifier Accuracy (BERT): 0.6380208333333334
# MLPClassifier Balanced Accuracy (BERT): 0.5269219903366245
# Classification Report for MLPClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.97      0.77       481
#  short-lived       0.61      0.09      0.15       287
#
#     accuracy                           0.64       768
#    macro avg       0.62      0.53      0.46       768
# weighted avg       0.63      0.64      0.54       768
#
# RandomForestClassifier Accuracy (BERT): 0.6171875
# RandomForestClassifier Balanced Accuracy (BERT): 0.5116952921830971
# Classification Report for RandomForestClassifier (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.63      0.93      0.75       481
#  short-lived       0.44      0.09      0.16       287
#
#     accuracy                           0.62       768
#    macro avg       0.54      0.51      0.45       768
# weighted avg       0.56      0.62      0.53       768
#
# SVC Accuracy (BERT): 0.6302083333333334
# SVC Balanced Accuracy (BERT): 0.5213876433388629
# Classification Report for SVC (BERT):
#               precision    recall  f1-score   support
#
#   long-lived       0.64      0.95      0.76       481
#  short-lived       0.53      0.09      0.15       287
#
#     accuracy                           0.63       768
#    macro avg       0.58      0.52      0.46       768
# weighted avg       0.60      0.63      0.54       768
